# %% [markdown]
# # 8. Neural Networks with Toy example

# %%
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 8.1 Generate Data

# %%
x = torch.linspace(-1, 1, 500)
y = x.pow(3) + 0.2*torch.rand(x.size())

plt.scatter(x.data.numpy(), y.data.numpy())
plt.show()

# %%
x.shape, y.shape
# Out:
# (torch.Size([500]), torch.Size([500]))

# %%
x = torch.unsqueeze(x, dim=1)
y = torch.unsqueeze(y, dim=1)

# %% [markdown]
# ## 8.2 Define Model

# %%
hidden1 = nn.Linear(1, 10, bias=True)
# activation1 = nn.ReLU()

hidden2 = nn.Linear(10, 20, bias=True)
# activation2 = nn.ReLU()

hidden3 = nn.Linear(20, 10, bias=True)
# activation3 = nn.ReLU()

output = nn.Linear(10, 1, bias=True)

# %%
model = nn.Sequential(
    hidden1, 
    hidden2, 
    hidden3, 
    output
)

# %%
loss = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# %% [markdown]
# ## 8.3 Train Model

# %%
for step in range(2000):
    pre = model(x)
    cost = loss(pre, y)
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    if step % 400  == 0:
        plt.scatter(x.data.numpy(), y.data.numpy())
        plt.plot(x.data.numpy(), pre.data.numpy(), 'r--', lw=4)
        plt.text(0.5, 0, 'Loss=%.4f' % cost.item(), fontdict={'size':10, 'color':'red'})
        plt.show()

# %% [markdown]
# # 추가

# %% [markdown]
# 특별히 참고할 코드가 깃허브 해당 리포에 없어서 그냥 위에꺼 파라미터 좀 바꿔서 돌려봤습니다

# %%
hidden1 = nn.Linear(1, 16, bias=True)
activation1 = nn.ReLU()

hidden2 = nn.Linear(16, 32, bias=True)
activation2 = nn.ReLU()

hidden3 = nn.Linear(32, 10, bias=True)
# activation3 = nn.ReLU()

output = nn.Linear(10, 1, bias=True)

# %%
model = nn.Sequential(
    hidden1, 
    activation1,
    hidden2,
    activation2,
    hidden3, 
    output
)

# %%
loss = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# %%
for step in range(2000):
    pre = model(x)
    cost = loss(pre, y)
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    if step % 400  == 0:
        plt.scatter(x.data.numpy(), y.data.numpy())
        plt.plot(x.data.numpy(), pre.data.numpy(), 'r--', lw=4)
        plt.text(0.5, 0, 'Loss=%.4f' % cost.item(), fontdict={'size':10, 'color':'red'})
        plt.show()
